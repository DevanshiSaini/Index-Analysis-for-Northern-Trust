# %% [markdown]
# ### Import the required library

# %%
import pandas as pd

# %% [markdown]
# ### Import the data files

# %% [markdown]
# Set the working directory

# %%
pwd
# Out:
# 'C:\\Users\\Dell'

# %%
cd D:\nifty50 and niftynext50 data
# Out:
# D:\nifty50 and niftynext50 data

# %% [markdown]
# Read the csv files

# %%
nifty50_sep=pd.read_csv("nifty50_sep.csv", index_col=0)
nifty50_oct=pd.read_csv("nifty50_oct.csv", index_col=0)
nifty50_nov=pd.read_csv("nifty50_nov.csv", index_col=0)
nifty50_dec=pd.read_csv("nifty50_dec.csv", index_col=0)
nifty50_jan=pd.read_csv("nifty50_jan.csv", index_col=0)
nifty50_feb=pd.read_csv("nifty50_feb.csv", index_col=0)
niftynext50_sep=pd.read_csv("niftynext50_sep.csv", index_col=0)
niftynext50_oct=pd.read_csv("niftynext50_oct.csv", index_col=0)
niftynext50_nov=pd.read_csv("niftynext50_nov.csv", index_col=0)
niftynext50_dec=pd.read_csv("niftynext50_dec.csv", index_col=0)
niftynext50_jan=pd.read_csv("niftynext50_jan.csv", index_col=0)
niftynext50_feb=pd.read_csv("niftynext50_feb.csv", index_col=0)

# %%
nifty50_sep.head(20)
# Out:
#        Security Symbol                               Security Name  \
# Sr. No
# 1           ADANIPORTS  Adani Ports and Special Economic Zone Ltd.
# 2           ASIANPAINT                           Asian Paints Ltd.
# 3             AXISBANK                              Axis Bank Ltd.
# 4           BAJAJ-AUTO                             Bajaj Auto Ltd.
# 5           BAJFINANCE                          Bajaj Finance Ltd.
# 6           BAJAJFINSV                          Bajaj Finserv Ltd.
# 7                 BPCL           Bharat Petroleum Corporation Ltd.
# 8           BHARTIARTL                          Bharti Airtel Ltd.
# 9             INFRATEL                        Bharti Infratel Ltd.
# 10               CIPLA                                  Cipla Ltd.
# 11           COALINDIA                             Coal India Ltd.
# 12             DRREDDY               Dr. Reddy's Laboratories Ltd.
# 13           EICHERMOT                          Eicher Motors Ltd.
# 14                GAIL                           GAIL (India) Ltd.
# 15              GRASIM                      Grasim Industries Ltd.
# 16             HCLTECH                       HCL Technologies Ltd.
# 17            HDFCBANK                              HDFC Bank Ltd.
# 18          HEROMOTOCO                          Hero MotoCorp Ltd.
# 19            HINDALCO                    Hindalco Industries Ltd.
# 20           HINDPETRO        Hindustan Petroleum Corporation Ltd.
#
#                               Industry  Equity Capital (In Rs.)  \
# Sr. No
# 1                             SHIPPING               4141903522
# 2                               PAINTS                959197790
# 3                                BANKS               5137681032
# 4       AUTOMOBILES - 2 AND 3 WHEELERS               2893670200
# 5                              FINANCE               1155936776
# 6                              FINANCE                795675485
# 7                           REFINERIES              21692527440
# 8         TELECOMMUNICATION - SERVICES              19987000535
# 9        TELECOMMUNICATION - EQUIPMENT              18496082460
# 10                     PHARMACEUTICALS               1610433594
# 11                              MINING              62074091770
# 12                     PHARMACEUTICALS                830149400
# 13            AUTOMOBILES - 4 WHEELERS                272677000
# 14                                 GAS              22550709330
# 15          CEMENT AND CEMENT PRODUCTS               1315182576
# 16                COMPUTERS - SOFTWARE               2785043328
# 17                               BANKS               5429877072
# 18      AUTOMOBILES - 2 AND 3 WHEELERS                399422910
# 19                           ALUMINIUM               2245349407
# 20                          REFINERIES              15238226250
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 1                                            25883.17           0.59  1.27
# 2                                            58304.93           1.34  0.74
# 3                                           108698.56           2.50  1.34
# 4                                            36549.99           0.84  1.02
# 5                                            51374.45           1.18  1.24
# 6                                            36320.29           0.83  1.22
# 7                                            29218.53           0.67  1.04
# 8                                            44659.55           1.03  1.25
# 9                                            22372.31           0.51  0.64
# 10                                           33179.08           0.76  0.86
# 11                                           36359.90           0.83  0.55
# 12                                           30671.94           0.70  0.69
# 13                                           32974.01           0.76  0.88
# 14                                           34186.88           0.78  0.75
# 15                                           40303.77           0.93  1.19
# 16                                           60591.40           1.39  0.36
# 17                                          430257.89           9.88  0.76
# 18                                           38077.24           0.87  0.72
# 19                                           33516.89           0.77  1.72
# 20                                           18775.09           0.43  1.16
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 1       0.25            1.85      -14.158946                  0.05
# 2       0.16            1.55       -5.767059                  0.03
# 3       0.22            1.66       -5.544859                  0.03
# 4       0.21            1.86       -2.091189                  0.03
# 5       0.19            2.52      -24.105580                  0.03
# 6       0.25            2.14      -10.990249                  0.04
# 7       0.12            2.39        3.327810                  0.02
# 8       0.15            2.08      -11.801485                  0.04
# 9       0.05            2.19       -8.347856                  0.04
# 10      0.13            1.37       -1.223288                  0.03
# 11      0.05            1.81       -6.889316                  0.04
# 12      0.06            1.78        1.550963                  0.03
# 13      0.14            2.31      -13.807500                  0.02
# 14      0.08            1.62        1.826975                  0.03
# 15      0.22            1.80       -4.309133                  0.03
# 16      0.02            1.15        3.951455                  0.02
# 17      0.27            1.13       -2.675626                  0.02
# 18      0.13            2.03       -9.851558                  0.02
# 19      0.27            2.44       -3.488128                  0.03
# 20      0.12            2.33       -0.925926                  0.03

# %% [markdown]
# ### Sorting the dataframes in descending order by 'Monthly Return'

# %%
nifty50_sep_byperformance=nifty50_sep.sort_values(by='Monthly Return', ascending=False)
nifty50_oct_byperformance=nifty50_oct.sort_values(by='Monthly Return', ascending=False)
nifty50_nov_byperformance=nifty50_nov.sort_values(by='Monthly Return', ascending=False)
nifty50_dec_byperformance=nifty50_dec.sort_values(by='Monthly Return', ascending=False)
nifty50_jan_byperformance=nifty50_jan.sort_values(by='Monthly Return', ascending=False)
nifty50_feb_byperformance=nifty50_feb.sort_values(by='Monthly Return', ascending=False)
niftynext50_sep_byperformance=niftynext50_sep.sort_values(by='Monthly Return', ascending=False)
niftynext50_oct_byperformance=niftynext50_oct.sort_values(by='Monthly Return', ascending=False)
niftynext50_nov_byperformance=niftynext50_nov.sort_values(by='Monthly Return', ascending=False)
niftynext50_dec_byperformance=niftynext50_dec.sort_values(by='Monthly Return', ascending=False)
niftynext50_jan_byperformance=niftynext50_jan.sort_values(by='Monthly Return', ascending=False)
niftynext50_feb_byperformance=niftynext50_feb.sort_values(by='Monthly Return', ascending=False)

# %% [markdown]
# ### Extracting top 5 stocks

# %%
nifty50_sep_topstocks=nifty50_sep_byperformance.iloc[:5,[1,5,9]]
nifty50_oct_topstocks=nifty50_oct_byperformance.iloc[:5,[1,5,9]]
nifty50_nov_topstocks=nifty50_nov_byperformance.iloc[:5,[1,5,9]]
nifty50_dec_topstocks=nifty50_dec_byperformance.iloc[:5,[1,5,9]]
nifty50_jan_topstocks=nifty50_jan_byperformance.iloc[:5,[1,5,9]]
nifty50_feb_topstocks=nifty50_feb_byperformance.iloc[:5,[1,5,9]]
niftynext50_sep_topstocks=niftynext50_sep_byperformance.iloc[:5,[1,5,9]]
niftynext50_oct_topstocks=niftynext50_oct_byperformance.iloc[:5,[1,5,9]]
niftynext50_nov_topstocks=niftynext50_nov_byperformance.iloc[:5,[1,5,9]]
niftynext50_dec_topstocks=niftynext50_dec_byperformance.iloc[:5,[1,5,9]]
niftynext50_jan_topstocks=niftynext50_jan_byperformance.iloc[:5,[1,5,9]]
niftynext50_feb_topstocks=niftynext50_feb_byperformance.iloc[:5,[1,5,9]]

# %% [markdown]
# ### Serialise

# %%
nifty50_sep_topstocks=nifty50_sep_topstocks.set_index('Security Name')
nifty50_oct_topstocks=nifty50_oct_topstocks.set_index('Security Name')
nifty50_nov_topstocks=nifty50_nov_topstocks.set_index('Security Name')
nifty50_dec_topstocks=nifty50_dec_topstocks.set_index('Security Name')
nifty50_jan_topstocks=nifty50_jan_topstocks.set_index('Security Name')
nifty50_feb_topstocks=nifty50_feb_topstocks.set_index('Security Name')
niftynext50_sep_topstocks=niftynext50_sep_topstocks.set_index('Security Name')
niftynext50_oct_topstocks=niftynext50_oct_topstocks.set_index('Security Name')
niftynext50_nov_topstocks=niftynext50_nov_topstocks.set_index('Security Name')
niftynext50_dec_topstocks=niftynext50_dec_topstocks.set_index('Security Name')
niftynext50_jan_topstocks=niftynext50_jan_topstocks.set_index('Security Name')
niftynext50_feb_topstocks=niftynext50_feb_topstocks.set_index('Security Name')

# %% [markdown]
# ### Final Output

# %% [markdown]
# #### 1. Nifty50 top stocks: September 2018

# %%
nifty50_sep_topstocks
# Out:
#                                    Weightage (%)  Monthly Return
# Security Name
# Wipro Ltd.                                  0.84        7.551867
# Tata Consultancy Services Ltd.              5.38        5.066397
# HCL Technologies Ltd.                       1.39        3.951455
# Bharat Petroleum Corporation Ltd.           0.67        3.327810
# Vedanta Ltd.                                0.99        2.020202

# %% [markdown]
# #### 2. Nifty50 top stocks: October 2018

# %%
nifty50_oct_topstocks
# Out:
#                                     Weightage (%)  Monthly Return
# Security Name
# ICICI Bank Ltd.                              5.52           16.18
# Bajaj Finance Ltd.                           1.36            9.90
# State Bank of India                          2.55            5.99
# Titan Company Ltd.                           0.85            4.84
# Zee Entertainment Enterprises Ltd.           0.61            2.85

# %% [markdown]
# #### 3. Nifty50 top stocks: November 2018

# %%
nifty50_nov_topstocks
# Out:
#                                             Weightage (%)  Monthly Return
# Security Name
# Bharat Petroleum Corporation Ltd.                    0.59           17.92
# Maruti Suzuki India Ltd.                             2.35           15.80
# Adani Ports and Special Economic Zone Ltd.           0.66           14.68
# IndusInd Bank Ltd.                                   1.93           14.50
# UltraTech Cement Ltd.                                0.96           14.30

# %% [markdown]
# #### 4. Nifty50 top stocks: December 2018

# %%
nifty50_dec_topstocks
# Out:
#                                       Weightage (%)  Monthly Return
# Security Name
# Indiabulls Housing Finance Ltd.                0.65           19.32
# Bharat Petroleum Corporation Ltd.              0.67           11.82
# Power Grid Corporation of India Ltd.           1.05           10.27
# Hindustan Petroleum Corporation Ltd.           0.44            9.00
# Bajaj Finserv Ltd.                             0.90            8.05

# %% [markdown]
# #### 5. Nifty50 top stocks: January 2019

# %%
nifty50_jan_topstocks
# Out:
#                           Weightage (%)  Monthly Return
# Security Name
# Axis Bank Ltd.                     2.96           16.58
# Infosys Ltd.                       6.57           13.75
# Bharti Infratel Ltd.               0.57           12.84
# Wipro Ltd.                         0.96           11.59
# Reliance Industries Ltd.           9.69            9.44

# %% [markdown]
# #### 6. Nifty50 top stocks: February 2019

# %%
nifty50_feb_topstocks
# Out:
#                                     Weightage (%)  Monthly Return
# Security Name
# Zee Entertainment Enterprises Ltd.           0.60           22.75
# Yes Bank Ltd.                                0.99           19.09
# Bajaj Auto Ltd.                              0.91           13.55
# Tech Mahindra Ltd.                           1.21           13.42
# UPL Ltd.                                     0.75           11.58

# %% [markdown]
# #### 7. Niftynext50 top stocks: September 2018

# %%
niftynext50_sep_topstocks
# Out:
#                                               Weightage (%)  Monthly Return
# Security Name
# Biocon Ltd.                                            2.27       10.793269
# ABB India Ltd.                                         1.17        7.749924
# Aurobindo Pharma Ltd.                                  3.27        4.447562
# Oil India Ltd.                                         0.93        2.785581
# ICICI Lombard General Insurance Company Ltd.           1.15        1.570648

# %% [markdown]
# #### 8. Niftynext50 top stocks: October 2018

# %%
niftynext50_nov_topstocks
# Out:
#                           Weightage (%)  Monthly Return
# Security Name
# Bandhan Bank Ltd.                  0.89           23.93
# Pidilite Industries Ltd.           2.74           21.32
# Shree Cement Ltd.                  3.11           18.47
# InterGlobe Aviation Ltd.           1.54           16.80
# United Spirits Ltd.                3.10           16.57

# %% [markdown]
# #### 9. Niftynext50 top stocks: November 2018

# %%
niftynext50_oct_topstocks
# Out:
#                                  Weightage (%)  Monthly Return
# Security Name
# Bharat Electronics Ltd.                   1.24           15.88
# United Spirits Ltd.                       2.76           12.15
# Bank of Baroda                            1.69           11.21
# SBI Life Insurance Company Ltd.           1.08            9.54
# Havells India Ltd.                        2.60            8.63

# %% [markdown]
# #### 10. Niftynext50 top stocks: December 2018

# %%
niftynext50_dec_topstocks
# Out:
#                                 Weightage (%)  Monthly Return
# Security Name
# Bandhan Bank Ltd.                        0.98           13.75
# Bank of Baroda                           1.69           13.09
# InterGlobe Aviation Ltd.                 1.67           12.21
# Colgate Palmolive (India) Ltd.           2.67           10.16
# Siemens Ltd.                             1.39           10.12

# %% [markdown]
# #### 11. Niftynext50 top stocks: January 2019

# %%
niftynext50_jan_topstocks
# Out:
#                        Weightage (%)  Monthly Return
# Security Name
# Aurobindo Pharma Ltd.           3.50            7.48
# Lupin Ltd.                      3.32            3.72
# Havells India Ltd.              2.82            3.17
# Biocon Ltd.                     2.15            3.06
# Dabur India Ltd.                3.97            3.02

# %% [markdown]
# #### 12. Niftynext50 top stocks: February 2019

# %%
niftynext50_feb_topstocks
# Out:
#                              Weightage (%)  Monthly Return
# Security Name
# Bandhan Bank Ltd.                     0.91           18.84
# Motherson Sumi Systems Ltd.           3.09           15.65
# Sun TV Network Ltd.                   0.95           14.74
# Piramal Enterprises Ltd.              3.24           14.47
# Aditya Birla Capital Ltd.             0.87           13.46

# %% [markdown]
# # -----------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Detailed Analysis

# %% [markdown]
# ## 1. Nifty50 : September 2018

# %% [markdown]
# ### Exploratory Data Analysis

# %%
nifty50_sep.head()
# Out:
#        Security Symbol                               Security Name  \
# Sr. No
# 1           ADANIPORTS  Adani Ports and Special Economic Zone Ltd.
# 2           ASIANPAINT                           Asian Paints Ltd.
# 3             AXISBANK                              Axis Bank Ltd.
# 4           BAJAJ-AUTO                             Bajaj Auto Ltd.
# 5           BAJFINANCE                          Bajaj Finance Ltd.
#
#                               Industry  Equity Capital (In Rs.)  \
# Sr. No
# 1                             SHIPPING               4141903522
# 2                               PAINTS                959197790
# 3                                BANKS               5137681032
# 4       AUTOMOBILES - 2 AND 3 WHEELERS               2893670200
# 5                              FINANCE               1155936776
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 1                                            25883.17           0.59  1.27
# 2                                            58304.93           1.34  0.74
# 3                                           108698.56           2.50  1.34
# 4                                            36549.99           0.84  1.02
# 5                                            51374.45           1.18  1.24
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 1       0.25            1.85      -14.158946                  0.05
# 2       0.16            1.55       -5.767059                  0.03
# 3       0.22            1.66       -5.544859                  0.03
# 4       0.21            1.86       -2.091189                  0.03
# 5       0.19            2.52      -24.105580                  0.03

# %%
nifty50_sep.columns
# Out:
# Index(['Security Symbol', 'Security Name', 'Industry',
#        'Equity Capital (In Rs.)',
#        'Free Float Market Capitalisation (Rs. Crores)', 'Weightage (%)',
#        'Beta', 'R2', 'Volatility (%)', 'Monthly Return',
#        'Avg. Impact Cost (%)'],
#       dtype='object')

# %%
nifty50_sep.shape
# Out:
# (50, 11)

# %%
nifty50_sep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1 to 50
# Data columns (total 11 columns):
# Security Symbol                                  50 non-null object
# Security Name                                    50 non-null object
# Industry                                         50 non-null object
# Equity Capital (In Rs.)                          50 non-null int64
# Free Float Market Capitalisation (Rs. Crores)    50 non-null float64
# Weightage (%)                                    50 non-null float64
# Beta                                             50 non-null float64
# R2                                               50 non-null float64
# Volatility (%)                                   50 non-null float64
# Monthly Return                                   50 non-null float64
# Avg. Impact Cost (%)                             50 non-null float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 4.7+ KB

# %% [markdown]
# Summary Statistics

# %%
nifty50_sep.describe()
# Out:
#        Equity Capital (In Rs.)  Free Float Market Capitalisation (Rs. Crores)  \
# count             5.000000e+01                                      50.000000
# mean              1.382760e+10                                   87101.662000
# std               2.252132e+10                                   97970.637728
# min               2.726770e+08                                   18775.090000
# 25%               1.748986e+09                                   33688.565000
# 50%               4.379078e+09                                   43271.515000
# 75%               1.270909e+10                                   94833.562500
# max               9.711810e+10                                  430565.740000
#
#        Weightage (%)       Beta         R2  Volatility (%)  Monthly Return  \
# count      50.000000  50.000000  50.000000       50.000000       50.000000
# mean        1.999400   1.028400   0.179400        1.945600       -7.367859
# std         2.250168   0.392758   0.093534        0.929358        9.310695
# min         0.430000   0.220000   0.010000        1.000000      -46.535662
# 25%         0.772500   0.742500   0.120000        1.542500      -10.946277
# 50%         0.995000   1.010000   0.185000        1.825000       -6.695279
# 75%         2.175000   1.247500   0.250000        2.117500       -1.709967
# max         9.890000   1.760000   0.380000        7.120000        7.551867
#
#        Avg. Impact Cost (%)
# count             50.000000
# mean               0.029400
# std                0.011323
# min                0.020000
# 25%                0.020000
# 50%                0.030000
# 75%                0.030000
# max                0.090000

# %% [markdown]
# ### Top 5 stocks by performance

# %% [markdown]
# Arranging the stocks in descending order by Monthly Returns

# %%
nifty50_sep_byperformance=nifty50_sep.sort_values(by='Monthly Return', ascending=False)

# %%
nifty50_sep_byperformance.head()
# Out:
#        Security Symbol                      Security Name  \
# Sr. No
# 48               WIPRO                         Wipro Ltd.
# 40                 TCS     Tata Consultancy Services Ltd.
# 16             HCLTECH              HCL Technologies Ltd.
# 7                 BPCL  Bharat Petroleum Corporation Ltd.
# 47                VEDL                       Vedanta Ltd.
#
#                     Industry  Equity Capital (In Rs.)  \
# Sr. No
# 48      COMPUTERS - SOFTWARE               9048094464
# 40      COMPUTERS - SOFTWARE               3828575182
# 16      COMPUTERS - SOFTWARE               2785043328
# 7                 REFINERIES              21692527440
# 47                    MINING               3717196639
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 48                                           36644.78           0.84  0.33
# 40                                          234092.87           5.38  0.22
# 16                                           60591.40           1.39  0.36
# 7                                            29218.53           0.67  1.04
# 47                                           43175.24           0.99  1.70
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 48      0.03            1.20        7.551867                  0.02
# 40      0.01            1.51        5.066397                  0.02
# 16      0.02            1.15        3.951455                  0.02
# 7       0.12            2.39        3.327810                  0.02
# 47      0.29            2.24        2.020202                  0.02

# %% [markdown]
# Extracting top 5 stocks

# %%
nifty50_sep_topstocks=nifty50_sep_byperformance.iloc[:5,[1,5,9]]

# %%
nifty50_sep_topstocks
# Out:
#                             Security Name  Weightage (%)  Monthly Return
# Sr. No
# 48                             Wipro Ltd.           0.84        7.551867
# 40         Tata Consultancy Services Ltd.           5.38        5.066397
# 16                  HCL Technologies Ltd.           1.39        3.951455
# 7       Bharat Petroleum Corporation Ltd.           0.67        3.327810
# 47                           Vedanta Ltd.           0.99        2.020202

# %% [markdown]
# ## 2. Nifty50 : October 2018

# %% [markdown]
# ### Exploratory Data Analysis

# %%
nifty50_oct.head()
# Out:
#        Security Symbol                               Security Name  \
# Sr. No
# 1           ADANIPORTS  Adani Ports and Special Economic Zone Ltd.
# 2           ASIANPAINT                           Asian Paints Ltd.
# 3             AXISBANK                              Axis Bank Ltd.
# 4           BAJAJ-AUTO                             Bajaj Auto Ltd.
# 5           BAJFINANCE                          Bajaj Finance Ltd.
#
#                               Industry  Equity Capital (In Rs.)  \
# Sr. No
# 1                             SHIPPING               4141903522
# 2                               PAINTS                959197790
# 3                                BANKS               5137681032
# 4       AUTOMOBILES - 2 AND 3 WHEELERS               2893670200
# 5                              FINANCE               1155936776
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 1                                            25092.27           0.61  1.32
# 2                                            55469.26           1.34  0.84
# 3                                           103230.40           2.49  1.28
# 4                                            35274.97           0.85  0.98
# 5                                            56458.58           1.36  1.51
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 1       0.30            3.17           -3.06                  0.04
# 2       0.23            2.40           -4.86                  0.02
# 3       0.28            2.80           -5.03                  0.03
# 4       0.23            2.09           -3.49                  0.04
# 5       0.28            4.46            9.90                  0.03

# %%
nifty50_oct.columns
# Out:
# Index(['Security Symbol', 'Security Name', 'Industry',
#        'Equity Capital (In Rs.)',
#        'Free Float Market Capitalisation (Rs. Crores)', 'Weightage (%)',
#        'Beta', 'R2', 'Volatility (%)', 'Monthly Return',
#        'Avg. Impact Cost (%)'],
#       dtype='object')

# %%
nifty50_oct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1 to 50
# Data columns (total 11 columns):
# Security Symbol                                  50 non-null object
# Security Name                                    50 non-null object
# Industry                                         50 non-null object
# Equity Capital (In Rs.)                          50 non-null int64
# Free Float Market Capitalisation (Rs. Crores)    50 non-null float64
# Weightage (%)                                    50 non-null float64
# Beta                                             50 non-null float64
# R2                                               50 non-null float64
# Volatility (%)                                   50 non-null float64
# Monthly Return                                   50 non-null float64
# Avg. Impact Cost (%)                             50 non-null float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 4.7+ KB

# %% [markdown]
# Summary Statistics

# %%
nifty50_oct.describe()
# Out:
#        Equity Capital (In Rs.)  Free Float Market Capitalisation (Rs. Crores)  \
# count             5.000000e+01                                      50.000000
# mean              1.382760e+10                                   82767.866400
# std               2.252132e+10                                   91782.910784
# min               2.726770e+08                                   16736.680000
# 25%               1.748986e+09                                   32734.007500
# 50%               4.379078e+09                                   38904.710000
# 75%               1.270909e+10                                   84157.195000
# max               9.711810e+10                                  410032.420000
#
#        Weightage (%)      Beta         R2  Volatility (%)  Monthly Return  \
# count       50.00000  50.00000  50.000000       50.000000       50.000000
# mean         2.00020   1.04360   0.210400        2.891400       -5.004400
# std          2.21829   0.38706   0.100488        1.327666        7.802877
# min          0.40000   0.30000   0.030000        0.980000      -26.470000
# 25%          0.79000   0.72750   0.132500        2.150000      -10.005000
# 50%          0.94000   1.07000   0.220000        2.595000       -4.510000
# 75%          2.03750   1.35000   0.287500        3.232500        0.342500
# max          9.91000   2.10000   0.420000        7.830000       16.180000
#
#        Avg. Impact Cost (%)
# count             50.000000
# mean               0.032800
# std                0.013254
# min                0.020000
# 25%                0.030000
# 50%                0.030000
# 75%                0.037500
# max                0.100000

# %% [markdown]
# ### Top 5 stocks by performance

# %% [markdown]
# Arranging the stocks in descending order by Monthly Returns

# %%
nifty50_oct_byperformance=nifty50_oct.sort_values(by='Monthly Return', ascending=False)

# %%
nifty50_oct_byperformance.head()
# Out:
#        Security Symbol                       Security Name  \
# Sr. No
# 24           ICICIBANK                     ICICI Bank Ltd.
# 5           BAJFINANCE                  Bajaj Finance Ltd.
# 38                SBIN                 State Bank of India
# 44               TITAN                  Titan Company Ltd.
# 50                ZEEL  Zee Entertainment Enterprises Ltd.
#
#                            Industry  Equity Capital (In Rs.)  \
# Sr. No
# 24                            BANKS              12868342266
# 5                           FINANCE               1155936776
# 38                            BANKS               8924587534
# 44      GEMS, JEWELLERY AND WATCHES                887786160
# 50            MEDIA & ENTERTAINMENT                960463070
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 24                                          228413.08           5.52  1.43
# 5                                            56458.58           1.36  1.51
# 38                                          105477.92           2.55  1.61
# 44                                           35241.74           0.85  1.00
# 50                                           25129.36           0.61  0.67
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 24      0.31            3.24           16.18                  0.03
# 5       0.28            4.46            9.90                  0.03
# 38      0.36            3.21            5.99                  0.02
# 44      0.13            2.63            4.84                  0.03
# 50      0.13            2.37            2.85                  0.03

# %% [markdown]
# Extracting top 5 stocks

# %%
nifty50_oct_topstocks=nifty50_oct_byperformance.iloc[:5,[1,5,9]]

# %%
nifty50_oct_topstocks
# Out:
#                              Security Name  Weightage (%)  Monthly Return
# Sr. No
# 24                         ICICI Bank Ltd.           5.52           16.18
# 5                       Bajaj Finance Ltd.           1.36            9.90
# 38                     State Bank of India           2.55            5.99
# 44                      Titan Company Ltd.           0.85            4.84
# 50      Zee Entertainment Enterprises Ltd.           0.61            2.85

# %% [markdown]
# ## 3. Nifty50 : November 2018

# %% [markdown]
# ### Exploratory Data Analysis

# %%
nifty50_nov.head()
# Out:
#        Security Symbol                               Security Name  \
# Sr. No
# 1           ADANIPORTS  Adani Ports and Special Economic Zone Ltd.
# 2           ASIANPAINT                           Asian Paints Ltd.
# 3             AXISBANK                              Axis Bank Ltd.
# 4           BAJAJ-AUTO                             Bajaj Auto Ltd.
# 5           BAJFINANCE                          Bajaj Finance Ltd.
#
#                               Industry  Equity Capital (In Rs.)  \
# Sr. No
# 1                             SHIPPING               4141903522
# 2                               PAINTS                959197790
# 3                                BANKS               5137681032
# 4       AUTOMOBILES - 2 AND 3 WHEELERS               2893670200
# 5                              FINANCE               1155936776
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 1                                            28775.25           0.66  1.33
# 2                                            60678.52           1.40  0.89
# 3                                           110914.18           2.56  1.24
# 4                                            37342.21           0.86  1.04
# 5                                            60135.13           1.39  1.46
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 1       0.30            1.87           14.68                  0.03
# 2       0.25            1.45            9.39                  0.02
# 3       0.27            1.66            7.44                  0.02
# 4       0.25            1.50            5.86                  0.03
# 5       0.26            1.82            6.51                  0.02

# %%
nifty50_nov.columns
# Out:
# Index(['Security Symbol', 'Security Name', 'Industry',
#        'Equity Capital (In Rs.)',
#        'Free Float Market Capitalisation (Rs. Crores)', 'Weightage (%)',
#        'Beta', 'R2', 'Volatility (%)', 'Monthly Return',
#        'Avg. Impact Cost (%)'],
#       dtype='object')

# %%
nifty50_nov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1 to 50
# Data columns (total 11 columns):
# Security Symbol                                  50 non-null object
# Security Name                                    50 non-null object
# Industry                                         50 non-null object
# Equity Capital (In Rs.)                          50 non-null int64
# Free Float Market Capitalisation (Rs. Crores)    50 non-null float64
# Weightage (%)                                    50 non-null float64
# Beta                                             50 non-null float64
# R2                                               50 non-null float64
# Volatility (%)                                   50 non-null float64
# Monthly Return                                   50 non-null float64
# Avg. Impact Cost (%)                             50 non-null float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 4.7+ KB

# %% [markdown]
# Summary Statistics

# %%
nifty50_nov.describe()
# Out:
#        Equity Capital (In Rs.)  Free Float Market Capitalisation (Rs. Crores)  \
# count             5.000000e+01                                      50.000000
# mean              1.382760e+10                                   86608.372800
# std               2.252132e+10                                   99858.430018
# min               2.726770e+08                                   17348.950000
# 25%               1.748986e+09                                   32098.647500
# 50%               4.379078e+09                                   39814.255000
# 75%               1.270909e+10                                   97216.290000
# max               9.711810e+10                                  456510.260000
#
#        Weightage (%)       Beta         R2  Volatility (%)  Monthly Return  \
# count      50.000000  50.000000  50.000000       50.000000       50.000000
# mean        1.999200   1.044400   0.210400        1.888600        2.464600
# std         2.306448   0.373697   0.100488        0.677598        8.858545
# min         0.400000   0.320000   0.030000        0.940000      -15.110000
# 25%         0.742500   0.747500   0.132500        1.502500       -4.297500
# 50%         0.920000   1.080000   0.230000        1.755000        3.460000
# 75%         2.245000   1.330000   0.280000        2.220000        9.957500
# max        10.540000   2.000000   0.430000        5.060000       17.920000
#
#        Avg. Impact Cost (%)
# count             50.000000
# mean               0.025400
# std                0.006455
# min                0.020000
# 25%                0.020000
# 50%                0.020000
# 75%                0.030000
# max                0.040000

# %% [markdown]
# ### Top 5 stocks by performance

# %% [markdown]
# Arranging the stocks in descending order by Monthly Returns

# %%
nifty50_nov_byperformance=nifty50_nov.sort_values(by='Monthly Return', ascending=False)

# %%
nifty50_nov_byperformance.head()
# Out:
#        Security Symbol                               Security Name  \
# Sr. No
# 7                 BPCL           Bharat Petroleum Corporation Ltd.
# 33              MARUTI                    Maruti Suzuki India Ltd.
# 1           ADANIPORTS  Adani Ports and Special Economic Zone Ltd.
# 27          INDUSINDBK                          IndusInd Bank Ltd.
# 46          ULTRACEMCO                       UltraTech Cement Ltd.
#
#                           Industry  Equity Capital (In Rs.)  \
# Sr. No
# 7                       REFINERIES              21692527440
# 33        AUTOMOBILES - 4 WHEELERS               1510400300
# 1                         SHIPPING               4141903522
# 27                           BANKS               6010120300
# 46      CEMENT AND CEMENT PRODUCTS               2746258690
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 7                                            25333.40           0.59  1.58
# 33                                          101834.33           2.35  1.11
# 1                                            28775.25           0.66  1.33
# 27                                           83362.17           1.93  0.93
# 46                                           41739.48           0.96  1.08
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 7       0.21            2.77           17.92                  0.03
# 33      0.33            1.92           15.80                  0.02
# 1       0.30            1.87           14.68                  0.03
# 27      0.23            1.95           14.50                  0.03
# 46      0.30            1.61           14.30                  0.03

# %% [markdown]
# Extracting top 5 stocks

# %%
nifty50_nov_topstocks=nifty50_nov_byperformance.iloc[:5,[1,5,9]]

# %%
nifty50_nov_topstocks
# Out:
#                                      Security Name  Weightage (%)  \
# Sr. No
# 7                Bharat Petroleum Corporation Ltd.           0.59
# 33                        Maruti Suzuki India Ltd.           2.35
# 1       Adani Ports and Special Economic Zone Ltd.           0.66
# 27                              IndusInd Bank Ltd.           1.93
# 46                           UltraTech Cement Ltd.           0.96
#
#         Monthly Return
# Sr. No
# 7                17.92
# 33               15.80
# 1                14.68
# 27               14.50
# 46               14.30

# %% [markdown]
# ## 4. Nifty50 : December 2018

# %% [markdown]
# ### Exploratory Data Analysis

# %%
nifty50_dec.head()
# Out:
#        Security Symbol                               Security Name  \
# Sr. No
# 1           ADANIPORTS  Adani Ports and Special Economic Zone Ltd.
# 2           ASIANPAINT                           Asian Paints Ltd.
# 3             AXISBANK                              Axis Bank Ltd.
# 4           BAJAJ-AUTO                             Bajaj Auto Ltd.
# 5           BAJFINANCE                          Bajaj Finance Ltd.
#
#                               Industry  Equity Capital (In Rs.)  \
# Sr. No
# 1                             SHIPPING               4141903522
# 2                               PAINTS                959197790
# 3                                BANKS               5139752272
# 4       AUTOMOBILES - 2 AND 3 WHEELERS               2893670200
# 5                              FINANCE               1155936776
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 1                                            30510.50           0.70  1.41
# 2                                            61900.25           1.42  0.94
# 3                                           109921.57           2.53  1.26
# 4                                            36994.72           0.85  1.03
# 5                                            62681.34           1.44  1.46
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 1       0.33            2.28            6.03                  0.03
# 2       0.27            1.87            2.01                  0.02
# 3       0.28            1.55           -0.93                  0.02
# 4       0.26            1.58           -0.93                  0.03
# 5       0.27            1.69            4.23                  0.02

# %%
nifty50_dec.columns
# Out:
# Index(['Security Symbol', 'Security Name', 'Industry',
#        'Equity Capital (In Rs.)',
#        'Free Float Market Capitalisation (Rs. Crores)', 'Weightage (%)',
#        'Beta', 'R2', 'Volatility (%)', 'Monthly Return',
#        'Avg. Impact Cost (%)'],
#       dtype='object')

# %%
nifty50_dec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1 to 50
# Data columns (total 11 columns):
# Security Symbol                                  50 non-null object
# Security Name                                    50 non-null object
# Industry                                         50 non-null object
# Equity Capital (In Rs.)                          50 non-null int64
# Free Float Market Capitalisation (Rs. Crores)    50 non-null float64
# Weightage (%)                                    50 non-null float64
# Beta                                             50 non-null float64
# R2                                               50 non-null float64
# Volatility (%)                                   50 non-null float64
# Monthly Return                                   50 non-null float64
# Avg. Impact Cost (%)                             50 non-null float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 4.7+ KB

# %% [markdown]
# Summary Statistics

# %%
nifty50_dec.describe()
# Out:
#        Equity Capital (In Rs.)  Free Float Market Capitalisation (Rs. Crores)  \
# count             5.000000e+01                                      50.000000
# mean              1.382822e+10                                   86920.510200
# std               2.252136e+10                                   98146.931588
# min               2.727475e+08                                   18909.500000
# 25%               1.749290e+09                                   32518.670000
# 50%               4.382905e+09                                   40786.450000
# 75%               1.272142e+10                                   94881.810000
# max               9.711810e+10                                  455658.290000
#
#        Weightage (%)       Beta         R2  Volatility (%)  Monthly Return  \
# count      50.000000  50.000000  50.000000       50.000000       50.000000
# mean        1.999200   1.038200   0.215600        1.794600        1.269600
# std         2.257753   0.362805   0.104689        0.564776        5.092039
# min         0.440000   0.330000   0.030000        1.010000      -12.610000
# 25%         0.750000   0.760000   0.127500        1.450000       -1.562500
# 50%         0.940000   1.100000   0.230000        1.650000        0.385000
# 75%         2.180000   1.330000   0.280000        1.980000        3.615000
# max        10.480000   2.070000   0.440000        3.890000       19.320000
#
#        Avg. Impact Cost (%)
# count             50.000000
# mean               0.025400
# std                0.006764
# min                0.010000
# 25%                0.020000
# 50%                0.020000
# 75%                0.030000
# max                0.040000

# %% [markdown]
# ### Top 5 stocks by performance

# %% [markdown]
# Arranging the stocks in descending order by Monthly Returns

# %%
nifty50_dec_byperformance=nifty50_dec.sort_values(by='Monthly Return', ascending=False)

# %%
nifty50_dec_byperformance.head()
# Out:
#        Security Symbol                         Security Name  \
# Sr. No
# 25          IBULHSGFIN       Indiabulls Housing Finance Ltd.
# 7                 BPCL     Bharat Petroleum Corporation Ltd.
# 36           POWERGRID  Power Grid Corporation of India Ltd.
# 20           HINDPETRO  Hindustan Petroleum Corporation Ltd.
# 6           BAJAJFINSV                    Bajaj Finserv Ltd.
#
#                  Industry  Equity Capital (In Rs.)  \
# Sr. No
# 25      FINANCE - HOUSING                853391352
# 7              REFINERIES              21692527440
# 36                  POWER              52315896480
# 20             REFINERIES              15238226250
# 6                 FINANCE                795680555
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 25                                           28418.06           0.65  2.07
# 7                                            29115.17           0.67  1.42
# 36                                           45727.23           1.05  0.54
# 20                                           18909.50           0.44  1.35
# 6                                            39167.23           0.90  1.42
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 25      0.27            3.89           19.32                  0.04
# 7       0.18            1.52           11.82                  0.03
# 36      0.12            1.39           10.27                  0.03
# 20      0.11            1.71            9.00                  0.03
# 6       0.34            2.15            8.05                  0.03

# %% [markdown]
# Extracting top 5 stocks

# %%
nifty50_dec_topstocks=nifty50_dec_byperformance.iloc[:5,[1,5,9]]

# %%
nifty50_dec_topstocks
# Out:
#                                Security Name  Weightage (%)  Monthly Return
# Sr. No
# 25           Indiabulls Housing Finance Ltd.           0.65           19.32
# 7          Bharat Petroleum Corporation Ltd.           0.67           11.82
# 36      Power Grid Corporation of India Ltd.           1.05           10.27
# 20      Hindustan Petroleum Corporation Ltd.           0.44            9.00
# 6                         Bajaj Finserv Ltd.           0.90            8.05

# %% [markdown]
# ## 5. Nifty50 : January 2019

# %% [markdown]
# ### Exploratory Data Analysis

# %%
nifty50_jan.head()
# Out:
#        Security Symbol                               Security Name  \
# Sr. No
# 1           ADANIPORTS  Adani Ports and Special Economic Zone Ltd.
# 2           ASIANPAINT                           Asian Paints Ltd.
# 3             AXISBANK                              Axis Bank Ltd.
# 4           BAJAJ-AUTO                             Bajaj Auto Ltd.
# 5           BAJFINANCE                          Bajaj Finance Ltd.
#
#                               Industry  Equity Capital (In Rs.)  \
# Sr. No
# 1                             SHIPPING               4141903522
# 2                               PAINTS                959197790
# 3                                BANKS               5139752272
# 4       AUTOMOBILES - 2 AND 3 WHEELERS               2893670200
# 5                              FINANCE               1155936776
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 1                                            26650.46           0.62  1.46
# 2                                            63683.25           1.47  0.92
# 3                                           128150.21           2.96  1.28
# 4                                            34742.52           0.80  1.01
# 5                                            61015.46           1.41  1.42
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 1       0.31            3.28          -12.65                  0.03
# 2       0.27            0.91            2.88                  0.01
# 3       0.29            1.85           16.58                  0.02
# 4       0.25            1.24           -6.09                  0.02
# 5       0.27            1.73           -2.66                  0.02

# %%
nifty50_jan.columns
# Out:
# Index(['Security Symbol', 'Security Name', 'Industry',
#        'Equity Capital (In Rs.)',
#        'Free Float Market Capitalisation (Rs. Crores)', 'Weightage (%)',
#        'Beta', 'R2', 'Volatility (%)', 'Monthly Return',
#        'Avg. Impact Cost (%)'],
#       dtype='object')

# %%
nifty50_jan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1 to 50
# Data columns (total 11 columns):
# Security Symbol                                  50 non-null object
# Security Name                                    50 non-null object
# Industry                                         50 non-null object
# Equity Capital (In Rs.)                          50 non-null int64
# Free Float Market Capitalisation (Rs. Crores)    50 non-null float64
# Weightage (%)                                    50 non-null float64
# Beta                                             50 non-null float64
# R2                                               50 non-null float64
# Volatility (%)                                   50 non-null float64
# Monthly Return                                   50 non-null float64
# Avg. Impact Cost (%)                             50 non-null float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 4.7+ KB

# %% [markdown]
# Summary Statistics

# %%
nifty50_jan.describe()
# Out:
#        Equity Capital (In Rs.)  Free Float Market Capitalisation (Rs. Crores)  \
# count             5.000000e+01                                      50.000000
# mean              1.382822e+10                                   86667.890400
# std               2.252136e+10                                  101454.446136
# min               2.727475e+08                                   17434.820000
# 25%               1.749290e+09                                   31064.437500
# 50%               4.382905e+09                                   40984.605000
# 75%               1.272142e+10                                   85464.760000
# max               9.711810e+10                                  446692.020000
#
#        Weightage (%)       Beta         R2  Volatility (%)  Monthly Return  \
# count      50.000000  50.000000  50.000000       50.000000         50.0000
# mean        2.000000   1.034400   0.217000        1.695600         -2.9826
# std         2.340997   0.359524   0.106814        0.919565          8.6495
# min         0.400000   0.270000   0.020000        0.830000        -22.1500
# 25%         0.715000   0.760000   0.130000        1.242500         -7.8175
# 50%         0.945000   1.095000   0.240000        1.505000         -2.5300
# 75%         1.975000   1.312500   0.287500        1.867500          2.4625
# max        10.310000   2.030000   0.460000        6.740000         16.5800
#
#        Avg. Impact Cost (%)
# count              50.00000
# mean                0.02300
# std                 0.00544
# min                 0.01000
# 25%                 0.02000
# 50%                 0.02000
# 75%                 0.03000
# max                 0.03000

# %% [markdown]
# ### Top 5 stocks by performance

# %% [markdown]
# Arranging the stocks in descending order by Monthly Returns

# %%
nifty50_jan_byperformance=nifty50_jan.sort_values(by='Monthly Return', ascending=False)

# %%
nifty50_jan_byperformance.head()
# Out:
#        Security Symbol             Security Name  \
# Sr. No
# 3             AXISBANK            Axis Bank Ltd.
# 28                INFY              Infosys Ltd.
# 9             INFRATEL      Bharti Infratel Ltd.
# 48               WIPRO                Wipro Ltd.
# 37            RELIANCE  Reliance Industries Ltd.
#
#                              Industry  Equity Capital (In Rs.)  \
# Sr. No
# 3                               BANKS               5139752272
# 28               COMPUTERS - SOFTWARE              21843026090
# 9       TELECOMMUNICATION - EQUIPMENT              18496082460
# 48               COMPUTERS - SOFTWARE               9048230346
# 37                         REFINERIES              63385607220
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 3                                           128150.21           2.96  1.28
# 28                                          284880.46           6.57  0.59
# 9                                            24865.21           0.57  0.27
# 48                                           41757.58           0.96  0.46
# 37                                          420031.70           9.69  1.38
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 3       0.29            1.85           16.58                  0.02
# 28      0.10            1.30           13.75                  0.02
# 9       0.02            2.59           12.84                  0.03
# 48      0.07            1.96           11.59                  0.02
# 37      0.44            1.70            9.44                  0.02

# %% [markdown]
# Extracting top 5 stocks

# %%
nifty50_jan_topstocks=nifty50_jan_byperformance.iloc[:5,[1,5,9]]

# %%
nifty50_jan_topstocks
# Out:
#                    Security Name  Weightage (%)  Monthly Return
# Sr. No
# 3                 Axis Bank Ltd.           2.96           16.58
# 28                  Infosys Ltd.           6.57           13.75
# 9           Bharti Infratel Ltd.           0.57           12.84
# 48                    Wipro Ltd.           0.96           11.59
# 37      Reliance Industries Ltd.           9.69            9.44

# %% [markdown]
# ## 6. Nifty50 : February 2019

# %% [markdown]
# ### Exploratory Data Analysis

# %%
nifty50_feb.head()
# Out:
#        Security Symbol                               Security Name  \
# Sr. No
# 1           ADANIPORTS  Adani Ports and Special Economic Zone Ltd.
# 2           ASIANPAINT                           Asian Paints Ltd.
# 3             AXISBANK                              Axis Bank Ltd.
# 4           BAJAJ-AUTO                             Bajaj Auto Ltd.
# 5           BAJFINANCE                          Bajaj Finance Ltd.
#
#                               Industry  Equity Capital (In Rs.)  \
# Sr. No
# 1                             SHIPPING               4141903522
# 2                               PAINTS                959197790
# 3                                BANKS               5139752272
# 4       AUTOMOBILES - 2 AND 3 WHEELERS               2893670200
# 5                              FINANCE               1155936776
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 1                                            25643.15           0.59  1.40
# 2                                            63349.64           1.47  0.98
# 3                                           125818.44           2.91  1.21
# 4                                            39448.88           0.91  0.95
# 5                                            62772.57           1.45  1.45
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 1       0.25            2.58           -3.78                  0.03
# 2       0.29            1.15           -0.52                  0.02
# 3       0.26            0.90           -1.82                  0.02
# 4       0.22            1.18           13.55                  0.02
# 5       0.28            1.45            2.88                  0.02

# %%
nifty50_feb.columns
# Out:
# Index(['Security Symbol', 'Security Name', 'Industry',
#        'Equity Capital (In Rs.)',
#        'Free Float Market Capitalisation (Rs. Crores)', 'Weightage (%)',
#        'Beta', 'R2', 'Volatility (%)', 'Monthly Return',
#        'Avg. Impact Cost (%)'],
#       dtype='object')

# %%
nifty50_feb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1 to 50
# Data columns (total 11 columns):
# Security Symbol                                  50 non-null object
# Security Name                                    50 non-null object
# Industry                                         50 non-null object
# Equity Capital (In Rs.)                          50 non-null int64
# Free Float Market Capitalisation (Rs. Crores)    50 non-null float64
# Weightage (%)                                    50 non-null float64
# Beta                                             50 non-null float64
# R2                                               50 non-null float64
# Volatility (%)                                   50 non-null float64
# Monthly Return                                   50 non-null float64
# Avg. Impact Cost (%)                             50 non-null float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 4.7+ KB

# %% [markdown]
# Summary Statistics

# %%
nifty50_feb.describe()
# Out:
#        Equity Capital (In Rs.)  Free Float Market Capitalisation (Rs. Crores)  \
# count             5.000000e+01                                      50.000000
# mean              1.382822e+10                                   86360.051000
# std               2.252136e+10                                   99683.646907
# min               2.727475e+08                                   16676.940000
# 25%               1.749290e+09                                   31588.280000
# 50%               4.382905e+09                                   42022.770000
# 75%               1.272142e+10                                   86938.782500
# max               9.711810e+10                                  446176.600000
#
#        Weightage (%)       Beta         R2  Volatility (%)  Monthly Return  \
# count      50.000000  50.000000  50.000000       50.000000       50.000000
# mean        2.000000   1.038000   0.206800        1.884800        1.689600
# std         2.308406   0.367906   0.103044        1.079182        6.607583
# min         0.390000   0.170000   0.010000        0.790000      -14.160000
# 25%         0.732500   0.775000   0.130000        1.270000       -2.100000
# 50%         0.970000   1.060000   0.215000        1.605000        0.400000
# 75%         2.012500   1.350000   0.280000        2.092500        4.945000
# max        10.330000   2.120000   0.440000        7.020000       22.750000
#
#        Avg. Impact Cost (%)
# count             50.000000
# mean               0.025800
# std                0.007025
# min                0.020000
# 25%                0.020000
# 50%                0.020000
# 75%                0.030000
# max                0.040000

# %% [markdown]
# ### Top 5 stocks by performance

# %% [markdown]
# Arranging the stocks in descending order by Monthly Returns

# %%
nifty50_feb_byperformance=nifty50_feb.sort_values(by='Monthly Return', ascending=False)

# %%
nifty50_feb_byperformance.head()
# Out:
#        Security Symbol                       Security Name  \
# Sr. No
# 50                ZEEL  Zee Entertainment Enterprises Ltd.
# 49             YESBANK                       Yes Bank Ltd.
# 4           BAJAJ-AUTO                     Bajaj Auto Ltd.
# 43               TECHM                  Tech Mahindra Ltd.
# 45                 UPL                            UPL Ltd.
#
#                               Industry  Equity Capital (In Rs.)  \
# Sr. No
# 50               MEDIA & ENTERTAINMENT                960466500
# 49                               BANKS               4623905770
# 4       AUTOMOBILES - 2 AND 3 WHEELERS               2893670200
# 43                COMPUTERS - SOFTWARE               4905969755
# 45        PESTICIDES AND AGROCHEMICALS               1018685340
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 50                                           25998.48           0.60  0.69
# 49                                           42752.63           0.99  1.09
# 4                                            39448.88           0.91  0.95
# 43                                           52130.44           1.21  0.71
# 45                                           32183.94           0.75  1.28
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 50      0.04            3.28           22.75                  0.04
# 49      0.05            7.02           19.09                  0.04
# 4       0.22            1.18           13.55                  0.02
# 43      0.09            1.94           13.42                  0.02
# 45      0.23            1.21           11.58                  0.02

# %% [markdown]
# Extracting top 5 stocks

# %%
nifty50_feb_topstocks=nifty50_feb_byperformance.iloc[:5,[1,5,9]]

# %%
nifty50_feb_topstocks
# Out:
#                              Security Name  Weightage (%)  Monthly Return
# Sr. No
# 50      Zee Entertainment Enterprises Ltd.           0.60           22.75
# 49                           Yes Bank Ltd.           0.99           19.09
# 4                          Bajaj Auto Ltd.           0.91           13.55
# 43                      Tech Mahindra Ltd.           1.21           13.42
# 45                                UPL Ltd.           0.75           11.58

# %% [markdown]
# ## 7. Niftynext50 : September 2018

# %% [markdown]
# ### Exploratory Data Analysis

# %%
niftynext50_sep.head()
# Out:
#        Security Symbol              Security Name                    Industry  \
# Sr. No
# 1                  ABB             ABB India Ltd.        ELECTRICAL EQUIPMENT
# 2                  ACC                   ACC Ltd.  CEMENT AND CEMENT PRODUCTS
# 3            ABCAPITAL  Aditya Birla Capital Ltd.                     FINANCE
# 4            AMBUJACEM        Ambuja Cements Ltd.  CEMENT AND CEMENT PRODUCTS
# 5             ASHOKLEY         Ashok Leyland Ltd.    AUTOMOBILES - 4 WHEELERS
#
#         Equity Capital (In Rs.)  \
# Sr. No
# 1                  4.238168e+08
# 2                  1.877872e+09
# 3                  2.201330e+10
# 4                  3.971290e+09
# 5                  2.935527e+09
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 1                                             7468.71           1.17  0.83
# 2                                            13118.01           2.05  1.13
# 3                                             6309.56           0.99  1.11
# 4                                            16423.97           2.57  1.16
# 5                                            17131.44           2.68  0.98
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 1       0.13            2.06        7.749924                  0.08
# 2       0.20            1.90       -5.272311                  0.04
# 3       0.18            1.70      -18.831858                  0.08
# 4       0.20            2.07       -7.375181                  0.05
# 5       0.09            1.95       -7.710190                  0.03

# %%
niftynext50_sep.columns
# Out:
# Index(['Security Symbol', 'Security Name', 'Industry',
#        'Equity Capital (In Rs.)',
#        'Free Float Market Capitalisation (Rs. Crores)', 'Weightage (%)',
#        'Beta', 'R2', 'Volatility (%)', 'Monthly Return',
#        'Avg. Impact Cost (%)'],
#       dtype='object')

# %%
niftynext50_sep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1 to 50
# Data columns (total 11 columns):
# Security Symbol                                  50 non-null object
# Security Name                                    50 non-null object
# Industry                                         50 non-null object
# Equity Capital (In Rs.)                          50 non-null float64
# Free Float Market Capitalisation (Rs. Crores)    50 non-null float64
# Weightage (%)                                    50 non-null float64
# Beta                                             50 non-null float64
# R2                                               50 non-null float64
# Volatility (%)                                   50 non-null float64
# Monthly Return                                   50 non-null float64
# Avg. Impact Cost (%)                             50 non-null float64
# dtypes: float64(8), object(3)
# memory usage: 4.7+ KB

# %% [markdown]
# Summary Statistics

# %%
niftynext50_sep.describe()
# Out:
#        Equity Capital (In Rs.)  Free Float Market Capitalisation (Rs. Crores)  \
# count             5.000000e+01                                      50.000000
# mean              9.050354e+09                                   12800.024000
# std               1.938434e+10                                    6434.628639
# min               4.241143e+07                                    5100.930000
# 25%               7.602659e+08                                    7372.747500
# 50%               2.436885e+09                                   11339.930000
# 75%               8.397978e+09                                   16640.262500
# max               1.030000e+11                                   34287.590000
#
#        Weightage (%)       Beta         R2  Volatility (%)  Monthly Return  \
# count      50.000000  50.000000  50.000000       50.000000       50.000000
# mean        1.999600   1.051000   0.142600        2.264600      -11.595533
# std         1.005465   0.452143   0.073867        0.673402        9.689559
# min         0.800000   0.060000   0.000000        1.090000      -34.946061
# 25%         1.155000   0.785000   0.080000        1.812500      -18.305163
# 50%         1.770000   1.090000   0.150000        2.150000      -10.839207
# 75%         2.600000   1.280000   0.197500        2.665000       -5.497071
# max         5.360000   2.300000   0.300000        4.220000       10.793269
#
#        Avg. Impact Cost (%)
# count             50.000000
# mean               0.061000
# std                0.026897
# min                0.030000
# 25%                0.050000
# 50%                0.050000
# 75%                0.070000
# max                0.180000

# %% [markdown]
# ### Top 5 stocks by performance

# %% [markdown]
# Arranging the stocks in descending order by Monthly Returns

# %%
niftynext50_sep_byperformance=niftynext50_sep.sort_values(by='Monthly Return', ascending=False)

# %%
niftynext50_sep_byperformance.head()
# Out:
#        Security Symbol                                 Security Name  \
# Sr. No
# 12              BIOCON                                   Biocon Ltd.
# 1                  ABB                                ABB India Ltd.
# 6           AUROPHARMA                         Aurobindo Pharma Ltd.
# 36                 OIL                                Oil India Ltd.
# 25             ICICIGI  ICICI Lombard General Insurance Company Ltd.
#
#                           Industry  Equity Capital (In Rs.)  \
# Sr. No
# 12                 PHARMACEUTICALS             3.000000e+09
# 1             ELECTRICAL EQUIPMENT             4.238168e+08
# 6                  PHARMACEUTICALS             5.859076e+08
# 36      OIL EXPLORATION/PRODUCTION             1.134904e+10
# 25                         FINANCE             4.540584e+09
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 12                                           14518.35           2.27  1.12
# 1                                             7468.71           1.17  0.83
# 6                                            20936.59           3.27  1.20
# 36                                            5980.04           0.93  0.51
# 25                                            7340.76           1.15  0.57
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 12      0.10            2.87       10.793269                  0.04
# 1       0.13            2.06        7.749924                  0.08
# 6       0.16            3.28        4.447562                  0.03
# 36      0.04            1.65        2.785581                  0.05
# 25      0.04            3.19        1.570648                  0.07

# %% [markdown]
# Extracting top 5 stocks

# %%
niftynext50_sep_topstocks=niftynext50_sep_byperformance.iloc[:5,[1,5,9]]

# %%
niftynext50_sep_topstocks
# Out:
#                                        Security Name  Weightage (%)  \
# Sr. No
# 12                                       Biocon Ltd.           2.27
# 1                                     ABB India Ltd.           1.17
# 6                              Aurobindo Pharma Ltd.           3.27
# 36                                    Oil India Ltd.           0.93
# 25      ICICI Lombard General Insurance Company Ltd.           1.15
#
#         Monthly Return
# Sr. No
# 12           10.793269
# 1             7.749924
# 6             4.447562
# 36            2.785581
# 25            1.570648

# %% [markdown]
# ## 8. Niftynext50 : October 2018

# %% [markdown]
# ### Exploratory Data Analysis

# %%
niftynext50_oct.head()
# Out:
#        Security Symbol              Security Name                    Industry  \
# Sr. No
# 1                  ABB             ABB India Ltd.        ELECTRICAL EQUIPMENT
# 2                  ACC                   ACC Ltd.  CEMENT AND CEMENT PRODUCTS
# 3            ABCAPITAL  Aditya Birla Capital Ltd.                     FINANCE
# 4            AMBUJACEM        Ambuja Cements Ltd.  CEMENT AND CEMENT PRODUCTS
# 5             ASHOKLEY         Ashok Leyland Ltd.    AUTOMOBILES - 4 WHEELERS
#
#         Equity Capital (In Rs.)  \
# Sr. No
# 1                  4.238168e+08
# 2                  1.877872e+09
# 3                  2.201330e+10
# 4                  3.971290e+09
# 5                  2.935527e+09
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 1                                             6776.56           1.09  0.85
# 2                                            11617.64           1.87  1.13
# 3                                             5753.73           0.92  1.21
# 4                                            14484.39           2.33  1.17
# 5                                            16498.54           2.65  1.15
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 1       0.17            1.89           -9.27                  0.09
# 2       0.23            2.49          -11.44                  0.03
# 3       0.24            2.93           -8.81                  0.06
# 4       0.25            2.33          -11.81                  0.04
# 5       0.14            3.02           -3.69                  0.03

# %%
niftynext50_oct.columns
# Out:
# Index(['Security Symbol', 'Security Name', 'Industry',
#        'Equity Capital (In Rs.)',
#        'Free Float Market Capitalisation (Rs. Crores)', 'Weightage (%)',
#        'Beta', 'R2', 'Volatility (%)', 'Monthly Return',
#        'Avg. Impact Cost (%)'],
#       dtype='object')

# %%
niftynext50_oct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1 to 50
# Data columns (total 11 columns):
# Security Symbol                                  50 non-null object
# Security Name                                    50 non-null object
# Industry                                         50 non-null object
# Equity Capital (In Rs.)                          50 non-null float64
# Free Float Market Capitalisation (Rs. Crores)    50 non-null float64
# Weightage (%)                                    50 non-null float64
# Beta                                             50 non-null float64
# R2                                               50 non-null float64
# Volatility (%)                                   50 non-null float64
# Monthly Return                                   50 non-null float64
# Avg. Impact Cost (%)                             50 non-null float64
# dtypes: float64(8), object(3)
# memory usage: 4.7+ KB

# %% [markdown]
# Summary Statistics

# %%
niftynext50_oct.describe()
# Out:
#        Equity Capital (In Rs.)  Free Float Market Capitalisation (Rs. Crores)  \
# count             5.000000e+01                                      50.000000
# mean              9.071407e+09                                   12451.876600
# std               1.937722e+10                                    6166.839411
# min               4.241143e+07                                    4654.920000
# 25%               7.602659e+08                                    7439.070000
# 50%               2.686352e+09                                   11077.895000
# 75%               8.397978e+09                                   16567.277500
# max               1.030000e+11                                   33231.320000
#
#        Weightage (%)       Beta         R2  Volatility (%)  Monthly Return  \
# count      50.000000  50.000000  50.000000       50.000000       50.000000
# mean        2.000200   1.010000   0.162600        2.696000       -2.280600
# std         0.990944   0.406503   0.083295        0.881085        7.915064
# min         0.750000   0.020000   0.000000        1.210000      -30.960000
# 25%         1.195000   0.805000   0.102500        2.170000       -5.667500
# 50%         1.780000   1.030000   0.170000        2.635000       -3.055000
# 75%         2.657500   1.217500   0.220000        3.042500        1.150000
# max         5.340000   1.890000   0.360000        5.370000       15.880000
#
#        Avg. Impact Cost (%)
# count             50.000000
# mean               0.064800
# std                0.042148
# min                0.030000
# 25%                0.050000
# 50%                0.050000
# 75%                0.067500
# max                0.290000

# %% [markdown]
# ### Top 5 stocks by performance

# %% [markdown]
# Arranging the stocks in descending order by Monthly Returns

# %%
niftynext50_oct_byperformance=niftynext50_oct.sort_values(by='Monthly Return', ascending=False)

# %%
niftynext50_oct_byperformance.head()
# Out:
#        Security Symbol                    Security Name  \
# Sr. No
# 10                 BEL          Bharat Electronics Ltd.
# 49          MCDOWELL-N              United Spirits Ltd.
# 9           BANKBARODA                   Bank of Baroda
# 42             SBILIFE  SBI Life Insurance Company Ltd.
# 23             HAVELLS               Havells India Ltd.
#
#                         Industry  Equity Capital (In Rs.)  \
# Sr. No
# 10      ELECTRONICS - INDUSTRIAL             2.436593e+09
# 49             BREW/DISTILLERIES             1.453277e+09
# 9                          BANKS             5.291032e+09
# 42                       FINANCE             1.000000e+10
# 23          ELECTRICAL EQUIPMENT             6.254729e+08
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 10                                            7708.65           1.24  1.01
# 49                                           17184.13           2.76  1.26
# 9                                            10538.15           1.69  1.71
# 42                                            6724.80           1.08  0.45
# 23                                           16157.22           2.60  1.20
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 10      0.09            3.13           15.88                  0.04
# 49      0.21            2.83           12.15                  0.06
# 9       0.21            2.99           11.21                  0.05
# 42      0.04            2.46            9.54                  0.08
# 23      0.22            2.85            8.63                  0.05

# %% [markdown]
# Extracting top 5 stocks

# %%
niftynext50_oct_topstocks=niftynext50_oct_byperformance.iloc[:5,[1,5,9]]

# %%
niftynext50_oct_topstocks
# Out:
#                           Security Name  Weightage (%)  Monthly Return
# Sr. No
# 10              Bharat Electronics Ltd.           1.24           15.88
# 49                  United Spirits Ltd.           2.76           12.15
# 9                        Bank of Baroda           1.69           11.21
# 42      SBI Life Insurance Company Ltd.           1.08            9.54
# 23                   Havells India Ltd.           2.60            8.63

# %% [markdown]
# ## 9. Niftynext50 : November 2018

# %% [markdown]
# ### Exploratory Data Analysis

# %%
niftynext50_nov.head()
# Out:
#        Security Symbol              Security Name                    Industry  \
# Sr. No
# 1                  ABB             ABB India Ltd.        ELECTRICAL EQUIPMENT
# 2                  ACC                   ACC Ltd.  CEMENT AND CEMENT PRODUCTS
# 3            ABCAPITAL  Aditya Birla Capital Ltd.                     FINANCE
# 4            AMBUJACEM        Ambuja Cements Ltd.  CEMENT AND CEMENT PRODUCTS
# 5             ASHOKLEY         Ashok Leyland Ltd.    AUTOMOBILES - 4 WHEELERS
#
#         Equity Capital (In Rs.)  \
# Sr. No
# 1                  4.238168e+08
# 2                  1.877872e+09
# 3                  2.201330e+10
# 4                  3.971290e+09
# 5                  2.935527e+09
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 1                                             7462.88           1.15  0.83
# 2                                            12553.10           1.94  1.18
# 3                                             5781.24           0.89  1.14
# 4                                            15975.81           2.47  1.22
# 5                                            16160.52           2.50  1.16
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 1       0.16            1.33           10.13                  0.05
# 2       0.25            1.67            8.05                  0.03
# 3       0.24            2.19            0.48                  0.07
# 4       0.28            1.33           10.30                  0.04
# 5       0.14            2.93           -2.05                  0.03

# %%
niftynext50_nov.columns
# Out:
# Index(['Security Symbol', 'Security Name', 'Industry',
#        'Equity Capital (In Rs.)',
#        'Free Float Market Capitalisation (Rs. Crores)', 'Weightage (%)',
#        'Beta', 'R2', 'Volatility (%)', 'Monthly Return',
#        'Avg. Impact Cost (%)'],
#       dtype='object')

# %%
niftynext50_nov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1 to 50
# Data columns (total 11 columns):
# Security Symbol                                  50 non-null object
# Security Name                                    50 non-null object
# Industry                                         50 non-null object
# Equity Capital (In Rs.)                          50 non-null float64
# Free Float Market Capitalisation (Rs. Crores)    50 non-null float64
# Weightage (%)                                    50 non-null float64
# Beta                                             50 non-null float64
# R2                                               50 non-null float64
# Volatility (%)                                   50 non-null float64
# Monthly Return                                   50 non-null float64
# Avg. Impact Cost (%)                             50 non-null float64
# dtypes: float64(8), object(3)
# memory usage: 4.7+ KB

# %% [markdown]
# Summary Statistics

# %%
niftynext50_nov.describe()
# Out:
#        Equity Capital (In Rs.)  Free Float Market Capitalisation (Rs. Crores)  \
# count             5.000000e+01                                      50.000000
# mean              9.071407e+09                                   12933.416400
# std               1.937722e+10                                    6766.000747
# min               4.241143e+07                                    4876.020000
# 25%               7.602659e+08                                    7490.130000
# 50%               2.686352e+09                                   11278.955000
# 75%               8.397978e+09                                   17042.445000
# max               1.030000e+11                                   37325.700000
#
#        Weightage (%)       Beta         R2  Volatility (%)  Monthly Return  \
# count      50.000000  50.000000  50.000000       50.000000       50.000000
# mean        1.999800   0.985600   0.158200        1.953200        2.920200
# std         1.046989   0.392393   0.081483        0.731776        8.971924
# min         0.750000   0.020000   0.000000        0.730000      -14.200000
# 25%         1.155000   0.735000   0.092500        1.425000       -4.445000
# 50%         1.745000   1.000000   0.160000        1.865000        2.090000
# 75%         2.635000   1.207500   0.210000        2.277500        8.880000
# max         5.770000   1.850000   0.340000        5.410000       23.930000
#
#        Avg. Impact Cost (%)
# count             50.000000
# mean               0.047800
# std                0.021973
# min                0.020000
# 25%                0.040000
# 50%                0.040000
# 75%                0.050000
# max                0.130000

# %% [markdown]
# ### Top 5 stocks by performance

# %% [markdown]
# Arranging the stocks in descending order by Monthly Returns

# %%
niftynext50_nov_byperformance=niftynext50_nov.sort_values(by='Monthly Return', ascending=False)

# %%
niftynext50_nov_byperformance.head()
# Out:
#        Security Symbol             Security Name                    Industry  \
# Sr. No
# 8           BANDHANBNK         Bandhan Bank Ltd.                       BANKS
# 39          PIDILITIND  Pidilite Industries Ltd.      CHEMICALS - SPECIALITY
# 43            SHREECEM         Shree Cement Ltd.  CEMENT AND CEMENT PRODUCTS
# 27              INDIGO  InterGlobe Aviation Ltd.        TRAVEL AND TRANSPORT
# 49          MCDOWELL-N       United Spirits Ltd.           BREW/DISTILLERIES
#
#         Equity Capital (In Rs.)  \
# Sr. No
# 8                  1.192805e+10
# 39                 5.078367e+08
# 43                 3.483722e+08
# 27                 3.844068e+09
# 49                 1.453277e+09
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 8                                             5769.00           0.89  1.34
# 39                                           17722.99           2.74  0.97
# 43                                           20103.07           3.11  1.01
# 27                                            9977.76           1.54  0.94
# 49                                           20032.27           3.10  1.18
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 8       0.12            2.51           23.93                  0.06
# 39      0.20            1.88           21.32                  0.04
# 43      0.21            1.63           18.47                  0.06
# 27      0.09            2.69           16.80                  0.03
# 49      0.18            2.46           16.57                  0.04

# %% [markdown]
# Extracting top 5 stocks

# %%
niftynext50_nov_topstocks=niftynext50_nov_byperformance.iloc[:5,[1,5,9]]

# %%
niftynext50_nov_topstocks
# Out:
#                    Security Name  Weightage (%)  Monthly Return
# Sr. No
# 8              Bandhan Bank Ltd.           0.89           23.93
# 39      Pidilite Industries Ltd.           2.74           21.32
# 43             Shree Cement Ltd.           3.11           18.47
# 27      InterGlobe Aviation Ltd.           1.54           16.80
# 49           United Spirits Ltd.           3.10           16.57

# %% [markdown]
# ## 10. Niftynext50 : December 2018

# %% [markdown]
# ### Exploratory Data Analysis

# %%
niftynext50_dec.head()
# Out:
#        Security Symbol              Security Name                    Industry  \
# Sr. No
# 1                  ABB             ABB India Ltd.        ELECTRICAL EQUIPMENT
# 2                  ACC                   ACC Ltd.  CEMENT AND CEMENT PRODUCTS
# 3            ABCAPITAL  Aditya Birla Capital Ltd.                     FINANCE
# 4            AMBUJACEM        Ambuja Cements Ltd.  CEMENT AND CEMENT PRODUCTS
# 5             ASHOKLEY         Ashok Leyland Ltd.    AUTOMOBILES - 4 WHEELERS
#
#         Equity Capital (In Rs.)  \
# Sr. No
# 1                  4.238168e+08
# 2                  1.877872e+09
# 3                  2.201396e+10
# 4                  3.971290e+09
# 5                  2.935527e+09
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 1                                             7081.71           1.06  0.77
# 2                                            12744.08           1.90  1.27
# 3                                             5943.77           0.89  1.15
# 4                                            16537.84           2.46  1.31
# 5                                            14743.69           2.20  1.15
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 1       0.14            1.46           -5.11                  0.05
# 2       0.29            2.03            1.52                  0.02
# 3       0.25            1.56           -4.81                  0.05
# 4       0.30            2.31            3.52                  0.04
# 5       0.15            1.82           -8.77                  0.03

# %%
niftynext50_dec.columns
# Out:
# Index(['Security Symbol', 'Security Name', 'Industry',
#        'Equity Capital (In Rs.)',
#        'Free Float Market Capitalisation (Rs. Crores)', 'Weightage (%)',
#        'Beta', 'R2', 'Volatility (%)', 'Monthly Return',
#        'Avg. Impact Cost (%)'],
#       dtype='object')

# %%
niftynext50_dec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1 to 50
# Data columns (total 11 columns):
# Security Symbol                                  50 non-null object
# Security Name                                    50 non-null object
# Industry                                         50 non-null object
# Equity Capital (In Rs.)                          50 non-null float64
# Free Float Market Capitalisation (Rs. Crores)    50 non-null float64
# Weightage (%)                                    50 non-null float64
# Beta                                             50 non-null float64
# R2                                               50 non-null float64
# Volatility (%)                                   50 non-null float64
# Monthly Return                                   50 non-null float64
# Avg. Impact Cost (%)                             50 non-null float64
# dtypes: float64(8), object(3)
# memory usage: 4.7+ KB

# %% [markdown]
# Summary Statistics

# %%
niftynext50_dec.describe()
# Out:
#        Equity Capital (In Rs.)  Free Float Market Capitalisation (Rs. Crores)  \
# count             5.000000e+01                                      50.000000
# mean              9.072290e+09                                   13420.177800
# std               1.937777e+10                                    6743.710154
# min               4.241143e+07                                    4443.420000
# 25%               7.603135e+08                                    8173.870000
# 50%               2.686352e+09                                   12618.875000
# 75%               8.397978e+09                                   17754.562500
# max               1.030000e+11                                   36685.690000
#
#        Weightage (%)       Beta         R2  Volatility (%)  Monthly Return  \
# count      50.000000  50.000000  50.000000       50.000000       50.000000
# mean        2.000600   0.983200   0.164800        1.838800        2.238600
# std         1.005106   0.388143   0.086902        0.519366        5.952195
# min         0.660000   0.040000   0.000000        0.680000       -9.590000
# 25%         1.215000   0.755000   0.092500        1.500000       -1.412500
# 50%         1.880000   1.000000   0.170000        1.795000        3.320000
# 75%         2.647500   1.207500   0.227500        2.140000        6.662500
# max         5.470000   1.840000   0.350000        3.040000       13.750000
#
#        Avg. Impact Cost (%)
# count             50.000000
# mean               0.045800
# std                0.019907
# min                0.020000
# 25%                0.032500
# 50%                0.040000
# 75%                0.050000
# max                0.110000

# %% [markdown]
# ### Top 5 stocks by performance

# %% [markdown]
# Arranging the stocks in descending order by Monthly Returns

# %%
niftynext50_dec_byperformance=niftynext50_dec.sort_values(by='Monthly Return', ascending=False)

# %%
niftynext50_dec_byperformance.head()
# Out:
#        Security Symbol                   Security Name              Industry  \
# Sr. No
# 8           BANDHANBNK               Bandhan Bank Ltd.                 BANKS
# 9           BANKBARODA                  Bank of Baroda                 BANKS
# 27              INDIGO        InterGlobe Aviation Ltd.  TRAVEL AND TRANSPORT
# 16              COLPAL  Colgate Palmolive (India) Ltd.         PERSONAL CARE
# 45             SIEMENS                    Siemens Ltd.  ELECTRICAL EQUIPMENT
#
#         Equity Capital (In Rs.)  \
# Sr. No
# 8                  1.192805e+10
# 9                  5.291032e+09
# 27                 3.844068e+09
# 16                 2.719856e+08
# 45                 7.122405e+08
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 8                                             6562.22           0.98  1.30
# 9                                            11314.34           1.69  1.62
# 27                                           11196.33           1.67  0.89
# 16                                           17905.89           2.67  0.43
# 45                                            9320.56           1.39  1.06
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 8       0.12            2.88           13.75                  0.05
# 9       0.21            1.50           13.09                  0.04
# 27      0.08            2.15           12.21                  0.03
# 16      0.07            2.03           10.16                  0.04
# 45      0.23            1.91           10.12                  0.03

# %% [markdown]
# Extracting top 5 stocks

# %%
niftynext50_dec_topstocks=niftynext50_dec_byperformance.iloc[:5,[1,5,9]]

# %%
niftynext50_dec_topstocks
# Out:
#                          Security Name  Weightage (%)  Monthly Return
# Sr. No
# 8                    Bandhan Bank Ltd.           0.98           13.75
# 9                       Bank of Baroda           1.69           13.09
# 27            InterGlobe Aviation Ltd.           1.67           12.21
# 16      Colgate Palmolive (India) Ltd.           2.67           10.16
# 45                        Siemens Ltd.           1.39           10.12

# %% [markdown]
# ## 11. Niftynext50 : January 2019

# %% [markdown]
# ### Exploratory Data Analysis

# %%
niftynext50_jan.head()
# Out:
#        Security Symbol              Security Name                    Industry  \
# Sr. No
# 1                  ABB             ABB India Ltd.        ELECTRICAL EQUIPMENT
# 2                  ACC                   ACC Ltd.  CEMENT AND CEMENT PRODUCTS
# 3            ABCAPITAL  Aditya Birla Capital Ltd.                     FINANCE
# 4            AMBUJACEM        Ambuja Cements Ltd.  CEMENT AND CEMENT PRODUCTS
# 5             ASHOKLEY         Ashok Leyland Ltd.    AUTOMOBILES - 4 WHEELERS
#
#         Equity Capital (In Rs.)  \
# Sr. No
# 1                  4.238168e+08
# 2                  1.877872e+09
# 3                  2.201396e+10
# 4                  3.971290e+09
# 5                  2.935527e+09
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 1                                             6740.28           1.07  0.69
# 2                                            12027.91           1.90  1.29
# 3                                             4814.45           0.76  1.17
# 4                                            15421.12           2.44  1.35
# 5                                            11694.26           1.85  1.09
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 1       0.13            1.39           -4.82                  0.05
# 2       0.31            1.33           -5.62                  0.03
# 3       0.26            1.32          -19.00                  0.05
# 4       0.33            1.50           -6.75                  0.03
# 5       0.14            1.54          -20.68                  0.03

# %%
niftynext50_jan.columns
# Out:
# Index(['Security Symbol', 'Security Name', 'Industry',
#        'Equity Capital (In Rs.)',
#        'Free Float Market Capitalisation (Rs. Crores)', 'Weightage (%)',
#        'Beta', 'R2', 'Volatility (%)', 'Monthly Return',
#        'Avg. Impact Cost (%)'],
#       dtype='object')

# %%
niftynext50_jan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1 to 50
# Data columns (total 11 columns):
# Security Symbol                                  50 non-null object
# Security Name                                    50 non-null object
# Industry                                         50 non-null object
# Equity Capital (In Rs.)                          50 non-null float64
# Free Float Market Capitalisation (Rs. Crores)    50 non-null float64
# Weightage (%)                                    50 non-null float64
# Beta                                             50 non-null float64
# R2                                               50 non-null float64
# Volatility (%)                                   50 non-null float64
# Monthly Return                                   50 non-null float64
# Avg. Impact Cost (%)                             50 non-null float64
# dtypes: float64(8), object(3)
# memory usage: 4.7+ KB

# %% [markdown]
# Summary Statistics

# %%
niftynext50_jan.describe()
# Out:
#        Equity Capital (In Rs.)  Free Float Market Capitalisation (Rs. Crores)  \
# count             5.000000e+01                                      50.000000
# mean              9.072290e+09                                   12647.123000
# std               1.937777e+10                                    6680.081457
# min               4.241143e+07                                    4322.290000
# 25%               7.603135e+08                                    7843.657500
# 50%               2.686352e+09                                   11843.060000
# 75%               8.397978e+09                                   17013.255000
# max               1.030000e+11                                   37654.820000
#
#        Weightage (%)       Beta        R2  Volatility (%)  Monthly Return  \
# count      50.000000  50.000000  50.00000       50.000000       50.000000
# mean        1.999600   0.966800   0.16460        1.564600       -6.487000
# std         1.055922   0.377961   0.08669        0.541081        7.698211
# min         0.680000   0.070000   0.00000        0.530000      -26.570000
# 25%         1.237500   0.720000   0.10000        1.282500      -12.352500
# 50%         1.875000   0.995000   0.17000        1.530000       -5.120000
# 75%         2.692500   1.167500   0.23750        1.820000       -0.082500
# max         5.950000   1.820000   0.35000        2.950000        7.480000
#
#        Avg. Impact Cost (%)
# count             50.000000
# mean               0.044400
# std                0.024173
# min                0.020000
# 25%                0.030000
# 50%                0.040000
# 75%                0.047500
# max                0.140000

# %% [markdown]
# ### Top 5 stocks by performance

# %% [markdown]
# Arranging the stocks in descending order by Monthly Returns

# %%
niftynext50_jan_byperformance=niftynext50_jan.sort_values(by='Monthly Return', ascending=False)

# %%
niftynext50_jan_byperformance.head()
# Out:
#        Security Symbol          Security Name              Industry  \
# Sr. No
# 6           AUROPHARMA  Aurobindo Pharma Ltd.       PHARMACEUTICALS
# 30               LUPIN             Lupin Ltd.       PHARMACEUTICALS
# 23             HAVELLS     Havells India Ltd.  ELECTRICAL EQUIPMENT
# 12              BIOCON            Biocon Ltd.       PHARMACEUTICALS
# 19               DABUR       Dabur India Ltd.         PERSONAL CARE
#
#         Equity Capital (In Rs.)  \
# Sr. No
# 6                  5.859076e+08
# 30                 9.045325e+08
# 23                 6.254729e+08
# 12                 3.000000e+09
# 19                 1.766264e+09
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 6                                            22155.74           3.50  1.06
# 30                                           20990.63           3.32  0.94
# 23                                           17849.75           2.82  1.13
# 12                                           13614.30           2.15  1.00
# 19                                           25075.30           3.97  0.90
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 6       0.18            1.55            7.48                  0.02
# 30      0.18            0.95            3.72                  0.03
# 23      0.24            1.63            3.17                  0.03
# 12      0.17            0.99            3.06                  0.03
# 19      0.18            1.30            3.02                  0.03

# %% [markdown]
# Extracting top 5 stocks

# %%
niftynext50_jan_topstocks=niftynext50_jan_byperformance.iloc[:5,[1,5,9]]

# %%
niftynext50_jan_topstocks
# Out:
#                 Security Name  Weightage (%)  Monthly Return
# Sr. No
# 6       Aurobindo Pharma Ltd.           3.50            7.48
# 30                 Lupin Ltd.           3.32            3.72
# 23         Havells India Ltd.           2.82            3.17
# 12                Biocon Ltd.           2.15            3.06
# 19           Dabur India Ltd.           3.97            3.02

# %% [markdown]
# ## 12. Niftynext50 : February 2019

# %% [markdown]
# ### Exploratory Data Analysis

# %%
niftynext50_feb.head()
# Out:
#        Security Symbol              Security Name                    Industry  \
# Sr. No
# 1                  ABB             ABB India Ltd.        ELECTRICAL EQUIPMENT
# 2                  ACC                   ACC Ltd.  CEMENT AND CEMENT PRODUCTS
# 3            ABCAPITAL  Aditya Birla Capital Ltd.                     FINANCE
# 4            AMBUJACEM        Ambuja Cements Ltd.  CEMENT AND CEMENT PRODUCTS
# 5             ASHOKLEY         Ashok Leyland Ltd.    AUTOMOBILES - 4 WHEELERS
#
#         Equity Capital (In Rs.)  \
# Sr. No
# 1                  4.238168e+08
# 2                  1.877872e+09
# 3                  2.201396e+10
# 4                  3.971290e+09
# 5                  2.935527e+09
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 1                                             6500.55           1.03  0.67
# 2                                            12019.04           1.91  1.26
# 3                                             5462.32           0.87  1.16
# 4                                            15579.07           2.47  1.40
# 5                                            12442.23           1.97  1.20
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 1       0.12            0.84           -3.56                  0.06
# 2       0.29            1.28           -0.07                  0.02
# 3       0.23            2.11           13.46                  0.06
# 4       0.35            1.56            1.02                  0.04
# 5       0.15            2.97            6.40                  0.04

# %%
niftynext50_feb.columns
# Out:
# Index(['Security Symbol', 'Security Name', 'Industry',
#        'Equity Capital (In Rs.)',
#        'Free Float Market Capitalisation (Rs. Crores)', 'Weightage (%)',
#        'Beta', 'R2', 'Volatility (%)', 'Monthly Return',
#        'Avg. Impact Cost (%)'],
#       dtype='object')

# %%
niftynext50_feb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1 to 50
# Data columns (total 11 columns):
# Security Symbol                                  50 non-null object
# Security Name                                    50 non-null object
# Industry                                         50 non-null object
# Equity Capital (In Rs.)                          50 non-null float64
# Free Float Market Capitalisation (Rs. Crores)    50 non-null float64
# Weightage (%)                                    50 non-null float64
# Beta                                             50 non-null float64
# R2                                               50 non-null float64
# Volatility (%)                                   50 non-null float64
# Monthly Return                                   50 non-null float64
# Avg. Impact Cost (%)                             50 non-null float64
# dtypes: float64(8), object(3)
# memory usage: 4.7+ KB

# %% [markdown]
# Summary Statistics

# %%
niftynext50_feb.describe()
# Out:
#        Equity Capital (In Rs.)  Free Float Market Capitalisation (Rs. Crores)  \
# count             5.000000e+01                                      50.000000
# mean              9.076902e+09                                   12613.262800
# std               1.937448e+10                                    6486.839039
# min               4.241143e+07                                    4264.200000
# 25%               7.603135e+08                                    7651.572500
# 50%               2.967764e+09                                   11589.795000
# 75%               8.397978e+09                                   16763.770000
# max               1.030000e+11                                   35996.820000
#
#        Weightage (%)       Beta        R2  Volatility (%)  Monthly Return  \
# count      50.000000  50.000000  50.00000       50.000000        50.00000
# mean        2.000600   0.963000   0.15600        1.797800         0.55840
# std         1.028711   0.380039   0.08454        0.608462         7.56342
# min         0.680000   0.090000   0.00000        0.840000       -12.78000
# 25%         1.212500   0.697500   0.09000        1.417500        -4.95500
# 50%         1.835000   0.960000   0.15500        1.600000        -0.24000
# 75%         2.660000   1.197500   0.23000        2.125000         5.23000
# max         5.710000   1.810000   0.35000        3.530000        18.84000
#
#        Avg. Impact Cost (%)
# count             50.000000
# mean               0.050000
# std                0.031816
# min                0.020000
# 25%                0.030000
# 50%                0.040000
# 75%                0.050000
# max                0.200000

# %% [markdown]
# ### Top 5 stocks by performance

# %% [markdown]
# Arranging the stocks in descending order by Monthly Returns

# %%
niftynext50_feb_byperformance=niftynext50_feb.sort_values(by='Monthly Return', ascending=False)

# %%
niftynext50_feb_byperformance.head()
# Out:
#        Security Symbol                Security Name               Industry  \
# Sr. No
# 8           BANDHANBNK            Bandhan Bank Ltd.                  BANKS
# 33          MOTHERSUMI  Motherson Sumi Systems Ltd.       AUTO ANCILLARIES
# 47               SUNTV          Sun TV Network Ltd.  MEDIA & ENTERTAINMENT
# 40                 PEL     Piramal Enterprises Ltd.        PHARMACEUTICALS
# 3            ABCAPITAL    Aditya Birla Capital Ltd.                FINANCE
#
#         Equity Capital (In Rs.)  \
# Sr. No
# 8                  1.192805e+10
# 33                 3.157934e+09
# 47                 1.970423e+09
# 40                 3.661695e+08
# 3                  2.201396e+10
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 8                                             5726.06           0.91  1.19
# 33                                           19512.24           3.09  1.23
# 47                                            5992.55           0.95  1.07
# 40                                           20445.88           3.24  1.60
# 3                                             5462.32           0.87  1.16
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 8       0.10            1.81           18.84                  0.04
# 33      0.16            3.53           15.65                  0.04
# 47      0.12            3.32           14.74                  0.04
# 40      0.25            2.19           14.47                  0.03
# 3       0.23            2.11           13.46                  0.06

# %% [markdown]
# Extracting top 5 stocks

# %%
niftynext50_feb_topstocks=niftynext50_feb_byperformance.iloc[:5,[1,5,9]]

# %%
niftynext50_feb_topstocks
# Out:
#                       Security Name  Weightage (%)  Monthly Return
# Sr. No
# 8                 Bandhan Bank Ltd.           0.91           18.84
# 33      Motherson Sumi Systems Ltd.           3.09           15.65
# 47              Sun TV Network Ltd.           0.95           14.74
# 40         Piramal Enterprises Ltd.           3.24           14.47
# 3         Aditya Birla Capital Ltd.           0.87           13.46

# %% [markdown]
# # -------------------------------------------------------------------

# %%
import plotly
import plotly.offline as pyo
import plotly.graph_objs as go
import plotly.figure_factory as ff
py.init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
plotly.tools.set_credentials_file(username='Devanshi', api_key='1a7VAfB8ovyuue1c2ujf')

# %%
nifty50_sep.head(10)
# Out:
#        Security Symbol                               Security Name  \
# Sr. No
# 1           ADANIPORTS  Adani Ports and Special Economic Zone Ltd.
# 2           ASIANPAINT                           Asian Paints Ltd.
# 3             AXISBANK                              Axis Bank Ltd.
# 4           BAJAJ-AUTO                             Bajaj Auto Ltd.
# 5           BAJFINANCE                          Bajaj Finance Ltd.
# 6           BAJAJFINSV                          Bajaj Finserv Ltd.
# 7                 BPCL           Bharat Petroleum Corporation Ltd.
# 8           BHARTIARTL                          Bharti Airtel Ltd.
# 9             INFRATEL                        Bharti Infratel Ltd.
# 10               CIPLA                                  Cipla Ltd.
#
#                               Industry  Equity Capital (In Rs.)  \
# Sr. No
# 1                             SHIPPING               4141903522
# 2                               PAINTS                959197790
# 3                                BANKS               5137681032
# 4       AUTOMOBILES - 2 AND 3 WHEELERS               2893670200
# 5                              FINANCE               1155936776
# 6                              FINANCE                795675485
# 7                           REFINERIES              21692527440
# 8         TELECOMMUNICATION - SERVICES              19987000535
# 9        TELECOMMUNICATION - EQUIPMENT              18496082460
# 10                     PHARMACEUTICALS               1610433594
#
#         Free Float Market Capitalisation (Rs. Crores)  Weightage (%)  Beta  \
# Sr. No
# 1                                            25883.17           0.59  1.27
# 2                                            58304.93           1.34  0.74
# 3                                           108698.56           2.50  1.34
# 4                                            36549.99           0.84  1.02
# 5                                            51374.45           1.18  1.24
# 6                                            36320.29           0.83  1.22
# 7                                            29218.53           0.67  1.04
# 8                                            44659.55           1.03  1.25
# 9                                            22372.31           0.51  0.64
# 10                                           33179.08           0.76  0.86
#
#           R2  Volatility (%)  Monthly Return  Avg. Impact Cost (%)
# Sr. No
# 1       0.25            1.85      -14.158946                  0.05
# 2       0.16            1.55       -5.767059                  0.03
# 3       0.22            1.66       -5.544859                  0.03
# 4       0.21            1.86       -2.091189                  0.03
# 5       0.19            2.52      -24.105580                  0.03
# 6       0.25            2.14      -10.990249                  0.04
# 7       0.12            2.39        3.327810                  0.02
# 8       0.15            2.08      -11.801485                  0.04
# 9       0.05            2.19       -8.347856                  0.04
# 10      0.13            1.37       -1.223288                  0.03
